# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Membaca file CSV
data = pd.read_csv('/content/UAS/kebutuhan_per_bulan_2.csv')

# %%
data
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %%
# Menampilkan scatter plot
plt.figure(figsize=(12, 6))  # Mengatur ukuran figure
plt.scatter(data['Propinsi'], data['tahun'], s=50, c='blue', alpha=0.7)

# Menambahkan label pada setiap titik data
for i in range(len(data)):
    plt.annotate(data['kebutuhan'][i], (data['Propinsi'][i], data['tahun'][i]), ha='center', va='bottom', fontsize=8)

# Menambahkan judul dan label sumbu
plt.title('PLOT 1 - Kebutuhan Per Tahun Berdasarkan Provinsi', fontsize=14)
plt.xlabel('Propinsi', fontsize=12)
plt.ylabel('Tahun', fontsize=12)

# Mengatur rotasi dan ukuran font label sumbu X
plt.xticks(rotation=90, fontsize=8)

# Menambahkan grid
plt.grid(True, linestyle='--', alpha=0.5)

# Menampilkan scatter plot
plt.tight_layout()
plt.show()

# %%
data_filtered_jabar = data[data['Propinsi'] == 'BALI']

plt.scatter(data_filtered_jabar['tahun'], data_filtered_jabar['kebutuhan'], c=data_filtered_jabar.index, cmap='rainbow', s=50, alpha=0.7)

plt.title('PLOT 2 - Kebutuhan per Tahun di Provinsi BALI')
plt.xlabel('Tahun')
plt.ylabel('Kebutuhan')

cbar = plt.colorbar()
cbar.set_label('Data Index')

plt.show()

# %%
# Membaca file CSV
df_transaksi = pd.read_csv("/content/UAS/transaksi2.csv", names=['date', 'id_product', 'quantity', 'id_penjualan'])
df_transaksi
# Out:
#                      date id_product  quantity  id_penjualan
# 0     2017-05-03 11:43:20      22704        25         15572
# 1     2017-09-04 07:16:20      22081        10         12461
# 2     2017-07-09 11:39:20      22989       100         12590
# 3     2017-03-20 12:18:20      22629        64         16839
# 4     2018-01-24 08:50:20      21615         1         13596
# ...                   ...        ...       ...           ...
# 7464  2018-01-24 09:17:20      22510         1         18156
# 7465  2018-02-02 09:49:20      20771         2         14606
# 7466  2017-03-23 12:52:20      22493        12         17001
# 7467  2017-10-25 10:28:20      23118         2         15856
# 7468  2017-07-19 09:54:20      23184         2         14769
#
# [7469 rows x 4 columns]

# %%
df_transaksi['date'] = pd.to_datetime(df_transaksi['date'])
df_transaksi['year'] = df_transaksi['date'].dt.year
df_transaksi['month'] = df_transaksi['date'].dt.month_name()
df_clean = df_transaksi.loc[df_transaksi['year'] == 2017]
# Melakukan pengelompokan dan penghitungan
plt.title('PLOT 3 - Data Transaksi Tahun 2017')
df_count = df_clean.groupby('month').count()
# Menampilkan scatter plot
plt.scatter(df_count['date'], df_count.index)

# %%
# Membaca file CSV
df_profile_pelanggan = pd.read_csv("/content/UAS/profile_pelanggan.csv", names=['kode', 'Kota'])
df_profile_pelanggan
# Out:
#        kode         Kota
# 0     15572  DKI Jakarta
# 1     12461   Jawa Timur
# 2     12590   Jawa Barat
# 3     16839  DKI Jakarta
# 4     13596  DKI Jakarta
# ...     ...          ...
# 2353  18261  DKI Jakarta
# 2354  18257  DKI Jakarta
# 2355  12510  Jawa Tengah
# 2356  16198  DKI Jakarta
# 2357  16235  DKI Jakarta
#
# [2358 rows x 2 columns]

# %%
# Membaca file CSV
df_SupplyKantor = pd.read_csv("/content/UAS/SupplyKantor.csv")
df_SupplyKantor
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %%
data_filtered = df_SupplyKantor [df_SupplyKantor['Kota']=='Bandung']
data_filtered
# Out:
#    TanggalPesan     Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 3     24-Apr-17  Bandung    Susan   Binder      81         19990
# 7     28-May-17  Bandung    Smith     Desk       2        125000
# 8     06-Jun-17  Bandung     Bobi   Pencil       7          1290
# 11    01-Jul-17  Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17  Bandung   Thomas   Binder      57         19990
# 15    04-Aug-17  Bandung    Susan      Pen      15         19990
# 19    07-Sep-17  Bandung    Smith   Pencil      67          1290
# 21    24-Sep-17  Bandung    Susan  Pen Set      74         15990
# 23    11-Oct-17  Bandung     Bobi   Binder      46          8990
# 25    28-Oct-17  Bandung    Smith   Binder      87         15000
# 28    22-Nov-17  Bandung     Bobi      Pen      27         19990
# 37    07-Feb-18  Bandung     Bobi   Pencil      53          1290
# 38    15-Feb-18  Bandung   Thomas   Pencil      32          1990
# ...

# %%
x = df_SupplyKantor['Jenis']
y = df_SupplyKantor['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Jenis Barang')
plt.ylabel('Jumlah')

plt.title('PLOT 4 - Jumlah Supply tiap barang di Kota Bandung')

plt.show()

# %%
data_filtered = df_SupplyKantor [df_SupplyKantor['Jenis']=='Pencil']
data_filtered
# Out:
#    TanggalPesan     Kota SalesRep   Jenis  Jumlah  Harga Satuan
# 8     06-Jun-17  Bandung     Bobi  Pencil       7          1290
# 19    07-Sep-17  Bandung    Smith  Pencil      67          1290
# 37    07-Feb-18  Bandung     Bobi  Pencil      53          1290
# 38    15-Feb-18  Bandung   Thomas  Pencil      32          1990
# 42    21-Mar-18  Bandung   Morgan  Pencil      90          4990

# %%
x = df_SupplyKantor['Jumlah']
y = df_SupplyKantor['TanggalPesan']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Jumlah')
plt.ylabel('Tanggal Pesan')

plt.title('PLOT 5 - Jumlah Supply Pensil di kota Bandung')

plt.show()

# %%
x = df_SupplyKantor['SalesRep']
y = df_SupplyKantor['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Sales')
plt.ylabel('Jumlah')

plt.title('PLOT 6 - Supplier Pensil di kota Bandung dan Jumlah Barangnya')

plt.show()
